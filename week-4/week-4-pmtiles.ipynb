# %%
import os
from wherobots import vtiles
from sedona.spark import *
from pyspark.sql.functions import *

# %%
config = SedonaContext.builder().getOrCreate()
sedona = SedonaContext.create(config)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Setting Spark log level to "WARN".
# 26/03/12 16:38:58 INFO core/src/lib.rs: Sedona native acceleration engine v0.12.0 ready

# %%
print(os.getenv("USER_S3_PATH"))
sedona.sql("SELECT COUNT(*) FROM org_catalog.gde_gold.analytics_gold").show()
# Out:
# s3://wbts-wbc-n9dlhzv9z2/742x8tgnc6/data/customer-tdmwyf6jnho3a9/
# [Stage 3:>                                                          (0 + 1) / 1]
# +--------+
# |count(1)|
# +--------+
# |     376|
# +--------+

# %%
base_s3_uri = f'{os.getenv("USER_S3_PATH")}PMTiles-example'
s3_destination_uri = f'{base_s3_uri}/data'

# %%
df = sedona.sql('''select *, 'homes' as layer from org_catalog.gde_gold.analytics_gold''')

# %%
s3_full_path = f"{base_s3_uri}/pmtiles/homes.pmtiles"
vtiles.generate_pmtiles(df, s3_full_path)

# %%
vtiles.show_pmtiles(s3_full_path)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3852cba704c73d04a0f587e67084171 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/pmtiles@2.7.1/dist/index.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/maplibre-gl@2.2.1/dist/maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://unpkg.com/@maplibre/maplibre-gl-leaflet@0.0.19/leaflet-maplibre-gl.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/maplibre-gl@2.4.0/dist/maplibre-gl.css&quot;/&gt;
#
#             &lt;style&gt;
#             .maplibregl-popup {
#                 font: 12px/20px &#x27;Helvetica Neue&#x27;, Arial, Helvetica, sans-serif;
#                 z-index: 651;
#             }
#             .feature-row{
#                 margin-bottom: 0.5em;
#                 &amp;:not(:last-of-type) {
#                     border-bottom: 1px solid black;
#                 }
#             }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3852cba704c73d04a0f587e67084171&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3852cba704c73d04a0f587e67084171 = L.map(
#                 &quot;map_b3852cba704c73d04a0f587e67084171&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b3852cba704c73d04a0f587e67084171);
#
#
#
#
#
#             var tile_layer_a5ad174759a35ff6303ddd1aa1957565 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5ad174759a35ff6303ddd1aa1957565.addTo(map_b3852cba704c73d04a0f587e67084171);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_b3852cba704c73d04a0f587e67084171);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_25d5800b18aaea48dcf9870c68e8b8e2 =
#                     new L.featureGroup().addTo(
#                         map_b3852cba704c73d04a0f587e67084171
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_25d5800b18aaea48dcf9870c68e8b8e2;
#             var draw_control_25d5800b18aaea48dcf9870c68e8b8e2 = new L.Control.Draw(
#                 options
#             ).addTo( map_b3852cba704c73d04a0f587e67084171 );
#             map_b3852cba704c73d04a0f587e67084171.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_25d5800b18aaea48dcf9870c68e8b8e2.addLayer(layer);
#             });
#             map_b3852cba704c73d04a0f587e67084171.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_25d5800b18aaea48dcf9870c68e8b8e2.addLayer(e.layer);
#             });
#
#
#
#
#             var measure_control_44129c88c8bd061c01909213dea0f6e6 = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &

# %%
sedona.sql("SELECT COUNT(*) FROM org_catalog.gde_gold.analytics_gold").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |     376|
# +--------+

# %%
sedona.sql("SELECT COUNT(*) FROM org_catalog.gde_gold.analytics_gold").ca
